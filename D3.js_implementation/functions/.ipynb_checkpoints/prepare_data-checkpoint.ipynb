# %%
import pandas as pd
import os

# %%
tree = pd.read_csv("../Daten/TREE2_Data_IWI_Open_Data_Vorlesung_2023_label.csv")
indeces = pd.read_csv("../Daten/cantons_indeces.csv")
indeces.set_index("aes_canton", inplace=True)
indeces = indeces.to_dict()["index"]

tree['aes_canton'] = tree['aes_canton'].map(indeces)

tree
# Out:
#       resp_id  aes_canton aes_langreg   t0sex               t0fmedu_comp
# 0     1011007          14      German    Male  Upper secondary education  \
# 1     1011011          10      French  Female  Upper secondary education
# 2     1011012           4      German  Female         Tertiary education
# 3     1011013          11      German  Female  Upper secondary education
# 4     1011017           5      German  Female  Compulsory schooling only
# ...       ...         ...         ...     ...                        ...
# 8424  9013473          11      German  Female         Tertiary education
# 8425  9013481          11      German    Male  Upper secondary education
# 8426  9013488           1      German  Female  Upper secondary education
# 8427  9013497          21     Italian  Female         Tertiary education
# 8428  9013499          20      German    Male                        NaN
#
#                                                 t0immig      t1bqvalids
# 0        Native (at least 1 parent born in Switzerland)  Valid response  \
# 1     First generation (respondent and parent(s) bor...  Valid response
# 2        Native (at least 1 parent born in Switzerland)  Valid response
# 3        Native (at least 1 parent born in Switzerland)  Valid response
# 4        Native (at least 1 parent born in Switzerland)  Valid response
# ...                                                 ...             ...
# 8424     Native (at least 1 parent born in Switzerland)  Valid response
# 8425     Native (at least 1 parent born in Switzerland)  Valid response
# 8426     Native (at least 1 parent born in Switzerland)  Valid response
# 8427     Native (at least 1 parent born in Switzerland)  Valid response
# 8428     Native (at least 1 parent born in Switzerland)  Valid response
#
#              t2bqvalids         t3bqvalids       t1wt       t2wt       t3wt
# 0     No valid response  No valid response   0.018611        NaN        NaN  \
# 1        Valid response     Valid response   4.959451   5.249187   4.995442
# 2        Valid response  No valid response   1.117837   1.230214        NaN
# 3        Valid response     Valid response   9.184840   9.340135  13.201428
# 4        Valid response  No valid response   4.415709   3.592895        NaN
# ...                 ...                ...        ...        ...        ...
# 8424     Valid response     Valid response   3.224725   3.078186   3.158450
# 8425     Valid response     Valid response  13.392653  11.988625  12.152623
# 8426     Valid response  No valid response  12.473951  10.524038        NaN
# 8427     Valid response     Valid response   9.101303  19.132431  11.100303
# 8428     Valid response     Valid response   6.598321   6.355939   4.833821
#
#      t0hisei08_3q t0wlem_3q
# 0          Medium    Medium  \
# 1            High    Medium
# 2          Medium    Medium
# 3             Low       Low
# 4             Low       Low
# ...           ...       ...
# 8424         High      High
# 8425       Medium      High
# 8426          Low       Low
# 8427       Medium      High
# 8428       Medium       Low
#
#                                         t0st_nprog_req3
# 0     Advanced requirements & Alternative/non-assign...  \
# 1                                Basic/low requirements
# 2     Advanced requirements & Alternative/non-assign...
# 3                                Basic/low requirements
# 4                                Basic/low requirements
# ...                                                 ...
# 8424  Advanced requirements & Alternative/non-assign...
# 8425                             Basic/low requirements
# 8426                             Basic/low requirements
# 8427                                  High requirements
# 8428                             Basic/low requirements
#
#                                        t1educ_class_1_r
# 0                                         3-4 years VET  \
# 1                           Other intermediate solution
# 2                        Vocational baccalaureate //VET
# 3                                           2 years VET
# 4                                         3-4 years VET
# ...                                                 ...
# 8424  Other general education programme (specialized...
# 8425                                      3-4 years VET
# 8426                                         Internship
# 8427                                         Internship
# 8428                                      3-4 years VET
#
#                                        t2educ_class_1_r
# 0                                                   NaN  \
# 1                                         3-4 years VET
# 2                        Vocational baccalaureate //VET
# 3                                           2 years VET
# 4                                         3-4 years VET
# ...                                                 ...
# 8424  Other general education programme (specialized...
# 8425                                      3-4 years VET
# 8426                                      3-4 years VET
# 8427                                         Internship
# 8428                                      3-4 years VET
#
#                                        t3educ_class_1_r
# 0                                                   NaN
# 1                                         3-4 years VET
# 2                                                   NaN
# 3                                                   NET
# 4                                                   NaN
# ...                                                 ...
# 8424  Other general education programme (specialized...
# 8425                                      3-4 years VET
# 8426                                                NaN
# 8427                     Vocational baccalaureate //VET
# 8428                                                NET
#
# [8429 rows x 18 columns]

# %%
#write to currated_data.csv

#df.to_csv("currated_data.csv", encoding='utf-8', index=False)
